# %% [markdown]
# <a href="https://colab.research.google.com/github/Tharun882/Simple-Linear-Regression-TV-Advertising-Data-/blob/main/Simple_Linear_Regression(TV_Advertising_Data).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing the libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # **Importing the dataset**

# %%
tv_sales=pd.read_csv('/content/tvmarketing.csv')

# %% [markdown]
# # **Check for missing values**

# %%
tv_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Sales   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %% [markdown]
# # **Spliting the dataset**

# %%
x=tv_sales.iloc[:,:-1].values
y=tv_sales.iloc[:,-1].values

# %% [markdown]
# # **Training the regression model**

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # **Predicting the testing set result**

# %%
y_pred=regressor.predict(x_test)

# %% [markdown]
# # **Visualising the training set result**

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('TV VS SALES')
plt.xlabel('TV')
plt.ylabel('SALES')
plt.show()

# %% [markdown]
# # **Visualising the testing set result**

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('TV VS SALES')
plt.xlabel('TV')
plt.ylabel('SALES')
plt.show()
